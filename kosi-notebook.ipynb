# %%
import pandas as pd

df = pd.read_csv('out.csv')
df
# Out:
#       timestamp  marginal_profit    pnl  \
# 0           100           -40248 -40248
# 1           300           -34803 -75051
# 2           500            15044 -60007
# 3          1300            10080 -49927
# 4          1400           -10072 -59999
# ...         ...              ...    ...
# 3565     998500           -20200  45512
# 3566     998700           -10110  35402
# 3567     998800           -15052  20350
# 3568     999500           -29882  -9532
# 3569     999600            -5048 -14580
#
#                                                  trades  \
# 0     (AMETHYSTS, US << MARKET, 10002, 1, 100)\n(STA...
# 1     (AMETHYSTS, US << MARKET, 9998, 1, 300)\n(AMET...
# 2     (AMETHYSTS, US << MARKET, 10004, 1, 500)\n(AME...
# 3     (STARFRUIT, MARKET << US, 5040, 1, 1300)\n(STA...
# 4     (STARFRUIT, US << MARKET, 5036, 1, 1400)\n(STA...
# ...                                                 ...
# 3565  (STARFRUIT, US << MARKET, 5050, 1, 998500)\n(S...
# ...

# %%
from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html(index=False).replace("\\n","<br>") ) )

# %%
pretty_print(df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>timestamp</th>
#       <th>marginal_profit</th>
#       <th>pnl</th>
#       <th>trades</th>
#       <th>position</th>
#       <th>actual_pnl</th>
#       <th>starfruit_price</th>
#       <th>amethyst_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>-40248</td>
#       <td>-40248</td>
#       <td>(AMETHYSTS, US &lt;&lt; MARKET, 10002, 1, 100)<br>(STARFRUIT, US &lt;&lt; MARKET, 5041, 1, 100)<br>(STARFRUIT, US &lt;&lt; MARKET, 5041, 1, 100)<br>(STARFRUIT, US &lt;&lt; MARKET, 5041, 1, 100)<br>(STARFRUIT, US &lt;&lt; MARKET, 5041, 1, 100)<br>(STARFRUIT, US &lt;&lt; MARKET, 5041, 1, 100)<br>(STARFRUIT, US &lt;&lt; MARKET, 5041, 1, 100)</td>
#       <td>{"AMETHYSTS": 1, "STARFRUIT": 6}</td>
#       <td>3</td>
#       <td>5042</td>
#       <td>9999</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>-34803</td>
#       <td>-75051</td>
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib widget

df.plot(x="timestamp", y="actual_pnl")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
