# %%
import pandas as pd

df = pd.read_csv('out.csv')
df
# Out:
#       timestamp  marginal_profit     pnl  \
# 0           100            50250   50250
# 1           300           -70290  -20040
# 2           500              -82  -20122
# 3          1300           -15120  -35242
# 4          1400             5036  -30206
# ...         ...              ...     ...
# 3565     998500            15150  111897
# 3566     998700            -5055  106842
# 3567     998800            -4952  101890
# 3568     999500           -29882   72008
# 3569     999600             5048   77056
#
#                                                  trades  \
# 0     (AMETHYSTS, MARKET << US, 10002, 1, 100)\n(AME...
# 1     (AMETHYSTS, US << MARKET, 9998, 1, 300)\n(AMET...
# 2     (AMETHYSTS, US << MARKET, 10002, 1, 500)\n(AME...
# 3     (STARFRUIT, US << MARKET, 5040, 1, 1300)\n(STA...
# 4              (STARFRUIT, MARKET << US, 5036, 1, 1400)
# ...                                                 ...
# 3565  (STARFRUIT, MARKET << US, 5050, 1, 998500)\n(S...
# 3566         (STARFRUIT, US << MARKET, 5055, 1, 998700)
# 3567  (AMETHYSTS, US << MARKET, 10002, 1, 998800)\n(...
# 3568  (AMETHYSTS, US << MARKET, 9995, 1, 999500)\n(A...
# 3569         (STARFRUIT, MARKET << US, 5048, 1, 999600)
#
#                                 position
# 0     {'AMETHYSTS': -2, 'STARFRUIT': -6}
# 1       {'AMETHYSTS': 1, 'STARFRUIT': 2}
# 2       {'AMETHYSTS': 0, 'STARFRUIT': 4}
# 3       {'AMETHYSTS': 0, 'STARFRUIT': 7}
# 4       {'AMETHYSTS': 0, 'STARFRUIT': 6}
# ...                                  ...
# 3565  {'AMETHYSTS': -14, 'STARFRUIT': 7}
# 3566  {'AMETHYSTS': -14, 'STARFRUIT': 8}
# 3567  {'AMETHYSTS': -13, 'STARFRUIT': 7}
# 3568   {'AMETHYSTS': -9, 'STARFRUIT': 5}
# 3569   {'AMETHYSTS': -9, 'STARFRUIT': 4}
#
# [3570 rows x 5 columns]

# %%
from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html(index=False).replace("\\n","<br>") ) )

# %%
pretty_print(df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>timestamp</th>
#       <th>marginal_profit</th>
#       <th>pnl</th>
#       <th>trades</th>
#       <th>position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>50250</td>
#       <td>50250</td>
#       <td>(AMETHYSTS, MARKET &lt;&lt; US, 10002, 1, 100)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10002, 1, 100)<br>(STARFRUIT, MARKET &lt;&lt; US, 5041, 1, 100)<br>(STARFRUIT, MARKET &lt;&lt; US, 5041, 1, 100)<br>(STARFRUIT, MARKET &lt;&lt; US, 5041, 1, 100)<br>(STARFRUIT, MARKET &lt;&lt; US, 5041, 1, 100)<br>(STARFRUIT, MARKET &lt;&lt; US, 5041, 1, 100)<br>(STARFRUIT, MARKET &lt;&lt; US, 5041, 1, 100)</td>
#       <td>{'AMETHYSTS': -2, 'STARFRUIT': -6}</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>-70290</td>
#       <td>-20040</td>
#       <td>(AMETHYSTS, US &lt;&lt; MARKET, 9998, 1, 300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9998, 1, 300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9998, 1, 300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9998, 1, 300)<br>(AMETHYSTS, MARKET &lt;&lt; US, 9998, 1, 300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 300)</td>
#       <td>{'AMETHYSTS': 1, 'STARFRUIT': 2}</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>-82</td>
#       <td>-20122</td>
#       <td>(AMETHYSTS, US &lt;&lt; MARKET, 10002, 1, 500)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10004, 1, 500)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10004, 1, 500)<br>(STARFRUIT, US &lt;&lt; MARKET, 5044, 1, 500)<br>(STARFRUIT, US &lt;&lt; MARKET, 5044, 1, 500)</td>
#       <td>{'AMETHYSTS': 0, 'STARFRUIT': 4}</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>-15120</td>
#       <td>-35242</td>
#       <td>(STARFRUIT, US &lt;&lt; MARKET, 5040, 1, 1300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5040, 1, 1300)<br>(STARFRUIT, US &lt;&lt; MARKET, 5040, 1, 1300)</td>
#       <td>{'AMETHYSTS': 0, 'STARFRUIT': 7}</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>5036</td>
#       <td>-30206</td>
#       <td>(STARFRUIT, MARKET &lt;&lt; US, 5036, 1, 1400)</td>
#       <td>{'AMETHYSTS': 0, 'STARFRUIT': 6}</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>25045</td>
#       <td>-5161</td>
#       <td>(AMETHYSTS, MARKET &lt;&lt; US, 10002, 1, 1500)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10002, 1, 1500)<br>(STARFRUIT, MARKET &lt;&lt; US, 5041, 1, 1500)</td>
#       <td>{'AMETHYSTS': -2, 'STARFRUIT': 5}</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>120060</td>
#       <td>114899</td>
#       <td>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 10005, 1, 1700)</td>
#       <td>{'AMETHYSTS': -14, 'STARFRUIT': 5}</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>-20168</td>
#       <td>94731</td>
#       <td>(STARFRUIT, US &lt;&lt; MARKET, 5042, 1, 2400)<br>(STARFRUIT, US &lt;&lt; MARKET, 5042, 1, 2400)<br>(STARFRUIT, US &lt;&lt; MARKET, 5042, 1, 2400)<br>(STARFRUIT, US &lt;&lt; MARKET, 5042, 1, 2400)</td>
#       <td>{'AMETHYSTS': -14, 'STARFRUIT': 9}</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>49990</td>
#       <td>144721</td>
#       <td>(AMETHYSTS, MARKET &lt;&lt; US, 9998, 1, 2700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 9998, 1, 2700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 9998, 1, 2700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 9998, 1, 2700)<br>(AMETHYSTS, MARKET &lt;&lt; US, 9998, 1, 2700)</td>
#       <td>{'AMETHYSTS': -19, 'STARFRUIT': 9}</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>5041</td>
#       <td>149762</td>
#       <td>(STARFRUIT, MARKET &lt;&lt; US, 5041, 1, 2800)</td>
#       <td>{'AMETHYSTS': -19, 'STARFRUIT': 8}</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>-19996</td>
#       <td>129766</td>
#       <td>(AMETHYSTS, US &lt;&lt; MARKET, 9998, 1, 2900)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9998, 1, 2900)</td>
#       <td>{'AMETHYSTS': -17, 'STARFRUIT': 8}</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>-5035</td>
#       <td>124731</td>
#       <td>(STARFRUIT, US &lt;&lt; MARKET, 5035, 1, 3100)</td>
#       <td>{'AMETHYSTS': -17, 'STARFRUIT': 9}</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>-19992</td>
#       <td>104739</td>
#       <td>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 3300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 3300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 3300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 3300)<br>(AMETHYSTS, MARKET &lt;&lt; US, 9996, 1, 3300)<br>(AMETHYSTS, MARKET &lt;&lt; US, 9996, 1, 3300)</td>
#       <td>{'AMETHYSTS': -15, 'STARFRUIT': 9}</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>-15108</td>
#       <td>89631</td>
#       <td>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 3700)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 3700)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 3700)<br>(STARFRUIT, US &lt;&lt; MARKET, 5037, 1, 3700)<br>(STARFRUIT, MARKET &lt;&lt; US, 5040, 1, 3700)</td>
#       <td>{'AMETHYSTS': -15, 'STARFRUIT': 12}</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>35238</td>
#       <td>124869</td>
#       <td>(STARFRUIT, MARKET &lt;&lt; US, 5034, 1, 3800)<br>(STARFRUIT, MARKET &lt;&lt; US, 5034, 1, 3800)<br>(STARFRUIT, MARKET &lt;&lt; US, 5034, 1, 3800)<br>(STARFRUIT, MARKET &lt;&lt; US, 5034, 1, 3800)<br>(STARFRUIT, MARKET &lt;&lt; US, 5034, 1, 3800)<br>(STARFRUIT, MARKET &lt;&lt; US, 5034, 1, 3800)<br>(STARFRUIT, MARKET &lt;&lt; US, 5034, 1, 3800)</td>
#       <td>{'AMETHYSTS': -15, 'STARFRUIT': 5}</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>25175</td>
#       <td>150044</td>
#       <td>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4200)<br>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4200)<br>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4200)<br>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4200)<br>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4200)</td>
#       <td>{'AMETHYSTS': -15, 'STARFRUIT': 0}</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>-69895</td>
#       <td>80149</td>
#       <td>(AMETHYSTS, US &lt;&lt; MARKET, 9995, 1, 4300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9995, 1, 4300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 4300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 4300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9995, 1, 4300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 4300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 4300)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9996, 1, 4300)<br>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4300)<br>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4300)</td>
#       <td>{'AMETHYSTS': -7, 'STARFRUIT': -2}</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>-9926</td>
#       <td>70223</td>
#       <td>(AMETHYSTS, US &lt;&lt; MARKET, 9998, 1, 4400)<br>(AMETHYSTS, US &lt;&lt; MARKET, 9998, 1, 4400)<br>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4400)<br>(STARFRUIT, MARKET &lt;&lt; US, 5035, 1, 4400)</td>
#       <td>{'AMETHYSTS': -5, 'STARFRUIT': -4}</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>-19928</td>
#       <td>50295</td>
#       <td>(AMETHYSTS, US &lt;&lt; MARKET, 10002, 1, 4800)<br>(AMETHYSTS, US &lt;&lt; MARKET, 10002, 1, 4800)<br>(AMETHYSTS, US &lt;&lt; MARKET, 10002, 1, 4800)<br>(STARFRUIT, MARKET &lt;&lt; US, 5039, 1, 4800)<br>(STARFRUIT, MARKET &lt;&lt; US, 5039, 1, 4800)</td>
#       <td>{'AMETHYSTS': -2, 'STARFRUIT': -6}</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>19996</
